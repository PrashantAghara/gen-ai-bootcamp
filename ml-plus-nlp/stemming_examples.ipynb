# %%
words = ["eating", "eats", "eaten", "writing", "written", "going", "goes", "gone"]

# %% [markdown]
# ### Types of Stemming

# %% [markdown]
# #### PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(f"{word} : {stemming.stem(word)}")
# Out:
# eating : eat
# eats : eat
# eaten : eaten
# writing : write
# written : written
# going : go
# goes : goe
# gone : gone

# %% [markdown]
# #### RegexpStemmer

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer("ing$|s$|e$|able$", min=4)

# %%
reg_stemmer.stem("writing")
# Out:
# 'writ'

# %%
reg_stemmer.stem("eating")
# Out:
# 'eat'

# %%
reg_stemmer.stem("ingeating")
# Out:
# 'ingeat'

# %% [markdown]
# #### SnowballStemmer

# %%
from nltk.stem import SnowballStemmer

# %%
snowball_stemmer = SnowballStemmer(language='english')

# %%
for word in words:
    print(f"{word} : {snowball_stemmer.stem(word)}")
# Out:
# eating : eat
# eats : eat
# eaten : eaten
# writing : write
# written : written
# going : go
# goes : goe
# gone : gone

# %%
print(f"{stemming.stem("fairly")} ----- {snowball_stemmer.stem("fairly")}")
# Out:
# fairli ----- fair

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
model = load_model('simple_rnn_imdb.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (32, 500, 128)         │     1,280,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (32, 128)              │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (32, 1)                │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,313,027 (5.01 MB)
#  Trainable params: 1,313,025 (5.01 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
model.get_weights()
# Out:
# [array([[-0.10154132,  0.33213356,  0.17266838, ..., -0.44265842,
#           0.21194366, -0.06847761],
#         [ 0.05220268,  0.08212015,  0.00682595, ..., -0.10513935,
#          -0.0153048 ,  0.05307026],
#         [-0.00499063,  0.0203078 , -0.04776896, ...,  0.05757118,
#          -0.00402408, -0.02393768],
#         ...,
#         [ 0.08414447,  0.06745175, -0.06719161, ..., -0.13159227,
#          -0.12931667,  0.12358117],
#         [-0.07735451, -0.13193725, -0.03249303, ...,  0.07207011,
#           0.08616449, -0.12286869],
#         [ 0.13081364,  0.05009172, -0.04814334, ..., -0.08804083,
#          -0.12336195,  0.05782587]], shape=(10000, 128), dtype=float32),
#  array([[-0.00520952, -0.10752388, -0.11338858, ...,  0.01118246,
#           0.04746773, -0.03693331],
#         [-0.12339278, -0.02069376,  0.00655142, ..., -0.02225379,
#           0.1505201 , -0.02603003],
#         [ 0.15786816,  0.05035334,  0.1601584 , ..., -0.02109496,
# ...

# %%
# Step 2: Helper Functions
# Function to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

# Function to preprocess user input
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### Prediction  function
def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)

    prediction=model.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
example_review_pos = "The Movie is fantasic! Amazing acting and great plot of the movie"

# %%
sentiment, score = predict_sentiment(example_review_pos)

print(f"Movie Review is {sentiment} with score {score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# Movie Review is Positive with score 0.5551600456237793

# %%
example_review_neg = 'Not a good movie'

sentiment, score = predict_sentiment(example_review_neg)

print(f"Movie Review is {sentiment} with score {score}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Movie Review is Negative with score 0.40183237195014954

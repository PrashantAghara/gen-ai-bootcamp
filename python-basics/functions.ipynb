# %%
def pos_args(*args):
    for arg in args:
        print(arg, end=" ")

pos_args(1, 2, 3, 4)
# Out:
# 1 2 3 4

# %%
def key_args(**kwargs):
    for key, val in kwargs.items():
        print(key, val)

key_args(name='prashant', age=26)
# Out:
# name prashant
# age 26

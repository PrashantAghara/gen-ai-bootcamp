# %%
import os
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="openai/gpt-oss-120b",
    huggingfacehub_api_token=os.getenv("HF_TOKEN"),
    temperature=0.7,
    timeout=120,
    max_new_tokens=256
)

model = ChatHuggingFace(llm=llm)

model.invoke("What is ML?")
# Out:
# AIMessage(content='**ML = Machine Learning**\n\nMachine Learning (ML) is a branch of artificial intelligence (AI) that gives computers the ability to **learn from data** and improve their performance on a task without being explicitly programmed for every possible scenario.\n\n---\n\n## Core Idea\n- **Traditional programming:** You write explicit rules (if‑else, loops) that tell the computer exactly what to do.\n- **Machine learning:** You feed the computer examples (data) and let it **discover patterns** and **build a model** that can make predictions or decisions on new, unseen data.\n\n---\n\n## How It Works (high‑level)\n\n1. **Collect Data** – Gather a dataset that reflects the problem you want to solve (e.g., images of cats/dogs, transaction histories, sensor readings).\n2. **Prepare & Clean** – Remove errors, handle missing values, normalize/scale, and possibly engineer new features.\n3. **Choose a Model** – Pick a mathematical structure (e.g., linear regression, decision', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 256, 'prompt_tokens': 71, 'total_tokens': 327}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_fa36a6363905c2b568a1', 'finish_reason': 'length', 'logprobs': None}, id='lc_run--019dd2d2-99e4-7c10-982b-1764c93e947d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 71, 'output_tokens': 256, 'total_tokens': 327})

# %%
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import LLMChain

template = """
Question : {question}
Answer : Lets think step by step.
"""

prompt = PromptTemplate(template=template, input_variables=['question'])

# %%
chain = LLMChain(llm=model, prompt=prompt)
chain.invoke("Who won the Men Cricket World cup 2023?")
# Out:
# {'question': 'Who won the Men Cricket World cup 2023?',
#  'text': '**Step‑by‑step reasoning**\n\n1. **Identify the tournament** – The question refers to the ICC\u202fMen’s Cricket World Cup held in 2023.  \n2. **Recall the final match** – The final was played on\u202f19\u202fNovember\u202f2023 at the\u202fNarendra Modi Stadium\u202fin Ahmedabad, India.  \n3. **Note the competing teams** – The two finalists were **Australia** and **India**.  \n4. **Check the result** – Australia chased the target'}

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['LANGCHAIN_API_KEY'] = os.getenv("LANGCHAIN_API_KEY")
os.environ['LANGCHAIN_TRACING_V2'] = "true" 
os.environ['LANGCHAIN_PROJECT'] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model="gemma:2b")
llm
# Out:
# OllamaLLM(model='gemma:2b')

# %%
result = llm.invoke("What is Gen AI?")

# %%
print(result)
# Out:
# Sure. Here's a simple explanation of Gen AI:
#
# **Gen AI stands for "Generative Artificial Intelligence".** It's a type of artificial intelligence that focuses on creating new content, like images, music, text, and more, based on existing data and patterns.
#
# Here are some key characteristics of Gen AI:
#
# * **Generative**: It focuses on creating entirely new content, unlike its predecessor, supervised AI, which focuses on learning from existing data.
# * **Creative**: It can generate new variations of existing content, like creating realistic photos, unique songs, or even generating text formats that are similar to human writing.
# * **Unsupervised**: It can learn from unlabeled data, unlike traditional AI models that require labeled data to be trained.
#
# **Here are some examples of Gen AI applications:**
#
# * **Image generation**: Creating realistic images of people, animals, objects, etc.
# * **Music composition**: Generating new musical pieces, including songs, instrumentals, and even entire albums.
# * **Text generation**: Creating realistic text formats, such as news articles, social media posts, and even emails.
# * **Video generation**: Creating new videos with different styles and content.
#
# **While it has potential to revolutionize many industries, it's important to note that Gen AI is still under development.** There are ethical and privacy concerns associated with its use, especially the potential for misuse for malicious purposes.
#
# I hope this provides a good overview of Gen AI. If you have any further questions, please let me know.

# %%
result = llm.invoke("What is Agentic AI?")
print(result)
# Out:
# **Agentic AI** is a type of artificial intelligence (AI) that focuses on enabling machines to act autonomously and intelligently in dynamic and uncertain environments. It involves developing AI systems that can:
#
# * **Observe and understand the physical and social world.**
# * **Make decisions and act accordingly.**
# * **Learn and adapt to changing circumstances.**
# * **Cooperate with humans and other agents.**
#
# **Key characteristics of Agentic AI include:**
#
# * **Self-awareness:** The ability to perceive and understand its own actions and the surrounding environment.
# * **Learning:** The ability to learn and adapt to new situations and data.
# * **Reasoning:** The ability to make logical inferences and solve problems.
# * **Planning:** The ability to plan and execute actions to achieve goals.
# * **Decision-making:** The ability to make informed decisions under uncertainty.
# * **Social intelligence:** The ability to interact with humans and other agents effectively.
#
# **Examples of Agentic AI systems include:**
#
# * **Dialogues:** AI-powered chatbots and virtual assistants that can engage in natural language conversations.
# * **Autonomous vehicles:** Cars that can navigate their surroundings and make decisions on their own.
# * **Medical diagnosis systems:** AI that can analyze medical data to diagnose diseases.
# * **Financial trading robots:** AI systems that can trade stocks and other assets.
#
# **Advantages of Agentic AI:**
#
# * **Increased efficiency:** Agents can perform tasks faster and more efficiently than humans.
# * **Improved accuracy:** Agents can reduce human error and ensure consistency in tasks.
# * **Enhanced decision-making:** Agents can make better decisions based on real-time data.
# * **New opportunities:** Agentic AI can create new industries and applications.
#
# **Challenges of Agentic AI:**
#
# * **Data requirements:** Training agents requires vast amounts of data, which can be expensive and challenging to collect.
# * **Ethical considerations:** The development and use of highly autonomous agents raises ethical concerns, such as privacy, transparency, and accountability.
# * **Safety and security:** Ensuring the safety and security of autonomous agents is crucial.

# %% [markdown]
# ### Chat Prompt

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide me answers based on questions"),
        ("user", "{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm

response = chain.invoke({"input": "Can you tell me about LangSmith?"})

print(response)
# Out:
# Sure, I can help! LangSmith is an open-source AI language model developed by Google. It is a large language model with a massive dataset of text and code, trained by Google AI.
#
# **Here's a summary of LangSmith:**
#
# * **Type:** Open-source AI language model
# * **Developer:** Google AI
# * **Size:** 175T (trillion tokens)
# * **Data:** Text and code
# * **Training:** Google AI
# * **Key features:**
#     * Multi-lingual (English, French, German, Chinese, Spanish, Portuguese)
#     * Large dataset
#     * Fine-tuned for various tasks
#     * Can generate human-quality text, translate languages, answer questions, and more
#
# **Here are some additional details about LangSmith:**
#
# * LangSmith was trained on a massive dataset of text and code, including Wikipedia, books, and other sources.
# * The model is trained by Google AI's Language Models team.
# * LangSmith is a powerful tool for a wide range of applications, including language translation, text generation, and question answering.
# * It is also a valuable resource for researchers in the field of artificial intelligence.
#
# **Here are some questions that I can help you answer about LangSmith:**
#
# * What is the size of the LangSmith dataset?
# * How is LangSmith different from other large language models?
# * What are some of the applications for LangSmith?
# * What are some resources for learning more about LangSmith?
#
# I hope this information is helpful. Please let me know if you have any other questions.

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()
chain = prompt|llm|parser
response = chain.invoke({"input": "Can you tell me about LangSmith?"})
print(response)
# Out:
# Sure, I can help with that. **LangSmith** is a large language model (LLM) trained by Google. It is a powerful language model with a massive dataset of text and code.
#
# **Key features of LangSmith:**
#
# * **Superhuman language capabilities:** It can generate human-quality text, translate languages, summarize text, and more.
# * **Large knowledge base:** It has access to a vast amount of information and can engage in deep conversations.
# * **Multi-modal skills:** It can process and generate content in different formats, including text, code, and images.
# * **Ethical and responsible usage:** Google has implemented safeguards to ensure its use aligns with ethical guidelines.
#
# **How can I help you further?**
#
# Please ask me any questions you have about LangSmith or any other topic related to artificial intelligence.
